# %% [markdown]
# <a href="https://colab.research.google.com/github/valren-enforcer/ML-Internship/blob/main/Walmart_Old.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [CSV Tutorial](https://www.analyticsvidhya.com/blog/2021/08/python-tutorial-working-with-csv-file-for-data-science/)
# [Quora](https://www.quora.com/How-do-I-import-a-CSV-file-to-a-variable-in-Python)
# [Basically linear regression in a nutshell](https://medium.com/@pritioli/implementing-linear-regression-from-scratch-747343634494)
# [Python Linear Regression](https://medium.com/@shuv.sdr/simple-linear-regression-in-python-a0069b325bf8)
# [Store Sale Predictions](https://medium.com/@adebayoaliyyah2020/forecasting-store-sales-using-regression-models-91a92e33a991)

# %%
# !pip install pandas
import numpy as np
import csv
import pandas as pd

# %%
walmart = pd.read_csv("Walmart.csv") #variable data is called “Data Frame” in programming term.
walmart
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
# @title Weekly_Sales

from matplotlib import pyplot as plt
walmart['Weekly_Sales'].plot(kind='hist', bins=20, title='Weekly_Sales')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
walmart.columns
walmart.Weekly_Sales
# Out:
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
type(walmart)
# Out:
# pandas.core.frame.DataFrame

# %%
walmart.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
import numpy as np # linear algebra
import seaborn as sns # data visualisation and plotting
import matplotlib.pyplot as plt # data plotting
import warnings

# Seaborn default configuration
sns.set_style("darkgrid")

# set the custom size for my graphs
sns.set(rc={'figure.figsize':(8.7,6.27)})

# filter all warnings
warnings.filterwarnings('ignore')

# set max column to 999 for displaying in pandas
pd.options.display.max_columns=999

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
#Load Data
data = walmart.copy()

# %%
#Preview Dataset
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.info() #nan = 0 (blank)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
data['Weekly_Sales'].value_counts() # make a new column called Target_Sales as y value and Date as x value
# Out:
# Weekly_Sales
# 760281.43     1
# 1643690.90    1
# 1641957.44    1
# 624081.64     1
# 757330.95     1
#              ..
# 1472515.79    1
# 1404429.92    1
# 1594968.28    1
# 1545418.53    1
# 1466058.28    1
# Name: count, Length: 6435, dtype: int64

# %%
rows, col = data.shape
print("Rows : %s, column : %s" % (rows, col))
# Out:
# Rows : 6435, column : 8

# %%
data = data[data['Weekly_Sales'].notnull()]

# %%
#snsdata = data.drop('Store', axis=1)
#g = sns.pairplot(snsdata, hue='Unemployment', markers='x')
#g = g.map_upper(plt.scatter)
#g = g.map_lower(sns.kdeplot)

# %%
data.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
#sns.violinplot(x=data.columns[0], y='Unemployment', data=data, inner='stick', palette='autumn')
#plt.show()
#sns.violinplot(x=data.columns[1], y='Unemployment', data=data, inner='stick', palette='autumn')
#plt.show()
#sns.violinplot(x=data.columns[2], y='Unemployment', data=data, inner='stick', palette='autumn')
#plt.show()
#sns.violinplot(x=data.columns[3], y='Unemployment', data=data, inner='stick', palette='autumn')
#plt.show()

# %%
#Multivariate Linear Regression Model
#mapping = {
    #'Store' : 1,
    #'Holiday_Flag' : 2,
    #'Temperature' : 3,
    #'Fuel_Price' : 4,
    #'CPI' : 5,
    #'Unemployment' : 6
#}

X = data.drop(['Date', 'Weekly_Sales'], axis=1).values # Input Feature Values #x, y values iteration, error
y = data.Weekly_Sales.replace(mapping).values.reshape(rows,1) # Output values

X = np.hstack(((np.ones((rows,1))), X))# Adding one more column for bias

# %%
X.shape
# Out:
# (6435, 7)

# %%
np.random.seed(42) # Let's set the zero for time being
theta = np.random.randn(1,5) # Setting values of theta randomly

print("Theta : %s" % (theta))
# Out:
# Theta : [[ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]]

# %%
x = np.squeeze(np.asarray(X)) #convert to array
t = np.squeeze(np.asarray(theta))

# %%
iteration = 10000
learning_rate = 0.006 # ~ 0.007, 0.005, originally 0.003 If you are going by formula, this is actually alpha. based on < derivative
J = np.zeros(iteration) # 1 x 10000 maxtix

# %%
# Let's train our model to compute values of theta
for i in range(iteration):
    # the predicted value is what we call y_hat
    y_hat = np.dot(X, theta.T) #transpose matrix, one-shot multiplication of matrixes to get error #GET HELP
    # the residue, or the error term is difference between what the
    # prediction was and what the true value is
    error = y_hat - y
    # we square the error (MSE) - why? to find error (largest in larger values)
    squared_error = error ** 2
    # now we sum up the error across all samples
    squared_error_sum = np.sum(squared_error)
    # we take the mean of this accumulated error
    J[i] = 1/(2 * rows) * squared_error_sum
    # this is the update rule -
    # we correct our estimate (theta) by a small faction of the gradient
    # gradient caclulation requires calculus - the
    theta -= ((learning_rate/rows) * np.dot(error.reshape(1,rows), X)) #learning rate 0.003; slow rate of movement down curve to get down to min value to avoid skipping of values

prediction = np.round(np.dot(X, theta.T))

ax = plt.subplot(111)
ax.plot(np.arange(iteration), J)
ax.set_ylim([0,0.15])
plt.ylabel("Cost Values", color="Green")
plt.xlabel("No. of Iterations", color="Green")
plt.title("Mean Squared Error vs Iterations")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-36cf43f8714f> in <cell line: 2>()
#       2 for i in range(iteration):
#       3     # the predicted value is what we call y_hat
# ----> 4     y_hat = np.dot(X, theta.T) #transpose matrix, one-shot multiplication of matrixes to get error
#       5     # the residue, or the error term is difference between what the
#       6     # prediction was and what the true value is
#
# ValueError: shapes (6435,7) and (5,1) not aligned: 7 (dim 1) != 5 (dim 0)

# %%
# this is the model
theta #weight w0 (not width or waist)
# Out:
# array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337]])

# %%
ax = plt.subplot(111)

ax.plot(np.arange(1, 151, 1), y, label='Orignal value', color='red')
ax.scatter(np.arange(1, 151, 1), prediction, label='Predicted Value')

#plt.xlabel("Dataset size", color="Green")
#plt.ylabel("Iris Flower (1-3)", color="Green")
#plt.title("Iris Flower (setosa = 1, versicolor = 2, virginica = 3)")

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d81661f05e03> in <cell line: 3>()
#       1 ax = plt.subplot(111)
#       2
# ----> 3 ax.plot(np.arange(1, 151, 1), y, label='Orignal value', color='red')
#       4 ax.scatter(np.arange(1, 151, 1), prediction, label='Predicted Value')
#       5
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# ...

# %%
accuracy = (sum(prediction == y)/float(len(y)) * 100)[0]
print("The model predicted values of Iris dataset with an overall accuracy of %s" % (accuracy))

# %%
#data.target not needed (not relevant to dataset)

# %%
# Open the CSV file in read mode
#with open('Walmart.csv', 'r') as csvfile:
  # Create a reader object
  #csv_reader = csv.reader(csvfile)

  # Iterate through the rows in the CSV file
  #for row in csv_reader:
    # Access each element in the row
    #print(row)

# %%
# Read the CSV file into a DataFrame
#df = pd.read_csv('Walmart.csv')

# Access data in the DataFrame using column names or indexing
#print(df['column_name'])
#print(df.iloc[0])  # Access first row
