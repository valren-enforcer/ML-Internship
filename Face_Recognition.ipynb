# %% [markdown]
# <a href="https://colab.research.google.com/github/valren-enforcer/ML-Internship/blob/main/Face_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vijjus/ST-summer-2024.git
# Out:
# fatal: destination path 'ST-summer-2024' already exists and is not an empty directory.

# %%
# !ls
# Out:
# random1.jpg  random2.jpg  sample_data  ST-summer-2024

# %%
# !pip3 install face_recognition

# %%
import face_recognition
import matplotlib.pyplot as plt

# %%
picture_of_me = face_recognition.load_image_file("keira.jpg")

# %%
plt.imshow(picture_of_me)

# %%
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0] #does not work on cartoon characters

# %%
type(my_face_encoding)
# Out:
# numpy.ndarray

# %%
my_face_encoding.shape
# Out:
# (128,)

# %%
my_face_encoding
# Out:
# array([-0.17458479,  0.09122644, -0.00573571, -0.0703368 , -0.16139483,
#        -0.00217001, -0.04947054, -0.02693897,  0.15671855, -0.00602973,
#         0.18801519, -0.02932487, -0.30245507,  0.01284245, -0.06575309,
#         0.20269415, -0.17982164, -0.10936201, -0.02503559, -0.11824526,
#         0.11215092,  0.07195877,  0.00264828,  0.12255132, -0.17309868,
#        -0.31622142,  0.03596558,  0.04802229, -0.06180573, -0.1351033 ,
#         0.06109689,  0.17274097, -0.20498961,  0.06928526,  0.02664774,
#         0.2323032 , -0.02796871, -0.09929474,  0.17500955,  0.09218548,
#        -0.21837598, -0.03370975,  0.10476638,  0.24936841,  0.20625864,
#        -0.02776723,  0.03789316, -0.08594191,  0.08260981, -0.34765309,
#         0.00562491,  0.22379489, -0.060866  ,  0.06483378,  0.0235481 ,
#        -0.27986753, -0.00527376,  0.05861065, -0.14196581, -0.09252287,
#         0.02241241, -0.05098822, -0.02080767, -0.10818139,  0.19957483,
# ...

# %%
picture1 = face_recognition.load_image_file("natalie.jpg")

# %%
plt.imshow(picture1)

# %%
picture1_encoding = face_recognition.face_encodings(picture1)[0]

# %%
results = face_recognition.compare_faces([my_face_encoding], picture1_encoding)

# %%
results #twins facial recognition false
# Out:
# [False]
